# %%
# !pip install newspaper3k
# !pip install tqdm
# Out:
# Requirement already satisfied: newspaper3k in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (0.2.8)
# Requirement already satisfied: requests>=2.10.0 in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from newspaper3k) (2.26.0)
# Requirement already satisfied: nltk>=3.2.1 in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from newspaper3k) (3.6.5)
# Requirement already satisfied: jieba3k>=0.35.1 in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: feedparser>=5.2.1 in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from newspaper3k) (6.0.10)
# Requirement already satisfied: Pillow>=3.3.0 in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from newspaper3k) (8.4.0)
# Requirement already satisfied: lxml>=3.6.0 in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from newspaper3k) (4.6.3)
# Requirement already satisfied: feedfinder2>=0.0.4 in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: PyYAML>=3.11 in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from newspaper3k) (6.0)
# Requirement already satisfied: tinysegmenter==0.3 in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from newspaper3k) (0.3)
# Requirement already satisfied: cssselect>=0.9.2 in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from newspaper3k) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from newspaper3k) (2.8.2)
# Requirement already satisfied: tldextract>=2.0.1 in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from newspaper3k) (3.4.1)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from newspaper3k) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.2.1)
# Requirement already satisfied: six in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Requirement already satisfied: sgmllib3k in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from feedparser>=5.2.1->newspaper3k) (1.0.0)
# Requirement already satisfied: click in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from nltk>=3.2.1->newspaper3k) (8.0.3)
# Requirement already satisfied: joblib in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from nltk>=3.2.1->newspaper3k) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from nltk>=3.2.1->newspaper3k) (2021.8.3)
# Requirement already satisfied: tqdm in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from nltk>=3.2.1->newspaper3k) (4.62.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.10.0->newspaper3k) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.10.0->newspaper3k) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.10.0->newspaper3k) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.10.0->newspaper3k) (3.2)
# Requirement already satisfied: filelock>=3.0.8 in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from tldextract>=2.0.1->newspaper3k) (3.3.1)
# Requirement already satisfied: requests-file>=1.4 in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (from tldextract>=2.0.1->newspaper3k) (1.5.1)
# Requirement already satisfied: tqdm in /Users/choimuseong/opt/anaconda3/lib/python3.9/site-packages (4.62.3)

# %%
import requests
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm
import json
import requests
import my_settings
import pandas as pd
from datetime import datetime
import urllib
from tqdm import tqdm
from newspaper import Article, ArticleException

# %%
def get_news(link):
    text_list = []
    article = Article(link, language='ko')
    try:
        article.download()
        article.parse()
    except ArticleException:
        return []
    title = article.title
    text = article.text
    text = title + '\n' + text
    text = text.replace('\n', '')
    if len(text) >= 2000:
        for i in range(1000,len(text)):
            if text[i] == '.':
                break
            else:
                i += 1
        text_fron = text[0:i]
        text_back = text[i+1:] 
        text_list.append(text_fron)
        text_list.append(text_back)
    else:
        text_list.append(text)
    return text_list

# %%
# 텍스트가 들어있는 리스트에 대해 api를 활용해서 요약하는 함수 (5줄)

def summary_news(news_list):
    result_list = []
    summary_url = 'https://naveropenapi.apigw.ntruss.com/text-summary/v1/summarize'
    headers = {
            'Accept': 'application/json;UTF-8',
            'Content-Type': 'application/json;UTF-8',
            'X-NCP-APIGW-API-KEY-ID': client_id,
            'X-NCP-APIGW-API-KEY': client_secret
        }
    for text in news_list:
        # 짧은 기사는 요약 없이 그대로 감정 분석
        if len(text.split('.')) < 5:
            result_list.append(text)
            continue
        else:
            data_summary = {
                "document": {
                    "content": text
                },
                "option": {
                    "language": "ko",
                    "model": "general",
                    "summaryCount": 5
                }
            }
            # API 요청 보내기
            response = requests.post(summary_url, data=json.dumps(data_summary), headers=headers)

            # API 응답 받기
            result = response.json()

            # 오류 걸러내기
            if "error" in result:
                continue
            else:
            # 요약 결과 출력
                text_sum = result["summary"]
                result_list.append(text_sum)
    text = ''.join(result_list)
    return text

# %%
# 요약된 텍스트에 대해 감정 분석 진행하여 감정 딕셔너리 생성
def sent_news(news):
    sentiments = {'neutral' : 0, 'positive' : 0, 'negative' : 0}
    sentiment_url = 'https://naveropenapi.apigw.ntruss.com/sentiment-analysis/v1/analyze'
    headers = {
            'Accept': 'application/json;UTF-8',
            'Content-Type': 'application/json;UTF-8',
            'X-NCP-APIGW-API-KEY-ID': client_id,
            'X-NCP-APIGW-API-KEY': client_secret
        }
    data_sentiment = {
        "content": news,
        "config": {
            "negativeClassification": True
        }
    }
    # API 요청 보내기
    response_sentiment = requests.post(sentiment_url, data=json.dumps(data_sentiment), headers=headers)

    # API 응답 받기
    result = response_sentiment.json()

    # 긍정, 부정, 중립 확률값 업데이트
    sentiments["neutral"] += result['document']["confidence"]["neutral"]
    sentiments["positive"] += result['document']["confidence"]["positive"]
    sentiments["negative"] += result['document']["confidence"]["negative"]
    return sentiments

# %%
# 해당하는 월로 파일 수정
news = pd.read_csv('news2023.csv')
for col in news.columns:
    try:
        pd.to_datetime(col)
    except ValueError:
        del news[col]

# %%
news_dict = {}
for col in news.columns:
    news_dict[col] = news[col].dropna().tolist()

# %%
sorted_keys = sorted(news_dict.keys())
start_date = sorted_keys[0]
end_date = sorted_keys[-1]

# %%
news_dict_int = {int(key): value for key, value in news_dict.items()}

# %%
datelist = pd.date_range(start=start_date, end=end_date).tolist()
datelist = [int(date.strftime("%Y%m%d")) for date in datelist]

# %%
df = pd.DataFrame(index=datelist, columns = {'pos','neu','neg'})

# %%
# 같은 폴더에 my_settings.py 파일 있어야 됨 -> 노션 참고
client_id = my_settings.CLIENT_ID
client_secret = my_settings.CLIENT_SECRET

# %%
# 실제 작업 하는 코드 -> 오래 걸림 !!!
avg_links = 67.4689042
for date, links in tqdm(news_dict_int.items()):
    # 뉴스 개수 세기
    num_link = 0
    pos = 0
    neg = 0
    neu = 0
    for link in links:
        news_list = get_news(link)
        if news_list == []:
            continue
        else:
            news_sum = summary_news(news_list)
            news_sent_dic = sent_news(news_sum)
            num_link += 1
            pos += news_sent_dic['positive']
            neg += news_sent_dic['negative']
            neu += news_sent_dic['neutral']
    weight = 1 / avg_links
    df.loc[date]['pos'] = pos * weight * 0.01
    df.loc[date]['neg'] = neg * weight * 0.01
    df.loc[date]['neu'] = neu * weight * 0.01
# Out:
# 100%|█████████████████████████████████████████| 77/77 [1:32:33<00:00, 72.12s/it]

# %%
sentiment = df.reset_index().rename(columns={'index': 'date'})
sentiment['date'] = pd.to_datetime(sentiment['date'], format='%Y%m%d')

# %%
stock = pd.read_csv('stock_macroeco.csv')

# %%
# 'date' 열을 날짜 자료형으로 변환
stock['date'] = pd.to_datetime(stock['date'])
sentiment['date'] = pd.to_datetime(sentiment['date'])

# 'date' 열의 값을 문자열 포맷으로 변경
stock['date'] = stock['date'].dt.strftime('%Y-%m-%d')
sentiment['date'] = sentiment['date'].dt.strftime('%Y-%m-%d')

# 두 데이터프레임 합치기
merged_df = pd.merge(stock, sentiment, on='date', how='inner')

# %%
merged_df
# Out:
#           date     CPI  interest  oil_price  gold_price exchange_rate(w/d)  \
# 0   2023-01-02  109.33      4.03       1343       74400           1,267.30
# 1   2023-01-03  109.36      4.00       1366       75150           1,268.90
# 2   2023-01-04  109.39      3.94       1364       75610           1,272.10
# 3   2023-01-05  109.41      3.89       1367       75960           1,274.70
# 4   2023-01-06  109.44      3.85       1369       75750           1,270.30
# ..         ...     ...       ...        ...         ...                ...
# 57  2023-03-27  110.54      3.54       1305       82290           1,289.70
# 58  2023-03-28  110.54      3.53       1287       81740           1,300.30
# 59  2023-03-29  110.55      3.53       1285       81950           1,297.40
# 60  2023-03-30  110.55      3.52       1287       81980           1,299.30
# 61  2023-03-31  110.56      3.50       1279       82270           1,303.80
#
#     KOSPI200(open)       pos       neu       neg
# 0           292.90   0.35206  0.200951  0.395573
# 1           290.64  0.408955  0.260933  0.263876
# 2           288.34   0.45672  0.422835  0.276532
# 3           297.65  0.488509  0.202006  0.183961
# 4           296.69  0.433137  0.291671  0.223777
# ..             ...       ...       ...       ...
# 57          314.83  0.345938  0.304357   0.29829
# 58          314.15    0.4314  0.282461  0.264368
# 59          315.68  0.401818   0.32393  0.267302
# 60          318.51  0.355095  0.316063  0.381179
# 61          319.60  0.502895  0.366898   0.41969
#
# [62 rows x 10 columns]

# %%
# 월 이름 바꿔서 저장해야 중복 X
merged_df.to_csv('2023_stock_macroeco_news.csv')
